# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). Especially around -20, and +20 we can observe the highest levels of temperatures. Latitude and temperature is correlated with bell curve. As it can on"LatvsTRemperature.png". More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy as ow
import scipy.stats as st
from datetime import datetime

# Import API key
from api_keys import wapi_key

# Settings
settings = {"units":"imperial","appid":wapi_key}

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 599

# %%
cities_df = pd.DataFrame({'city':cities})
cities_df.head()
# Out:
#             city
# 0         darnah
# 1      taolanaro
# 2        toliary
# 3  belushya guba
# 4        bubaque

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
weather_data = []

# API calls and store the response into a list
for index, row in cities_df.iterrows():
    # Try to grab weather information if they are available in OpenWeatherMap
    try:
        weather_data.append(ow.get_current(row[0],**settings))
        print(f'Processing Record {index} city: {row[0]} ! Appending weather')
        
    # Handle exceptions for not available cities
    except:
        print(f'city {row[0]} not found. Skipping...')
print("--------------------------")
print("Data Retrieval Complete")
print("--------------------------")
# Out:
# Processing Record 0 city: darnah ! Appending weather
# city taolanaro not found. Skipping...
# city toliary not found. Skipping...
# city belushya guba not found. Skipping...
# Processing Record 4 city: bubaque ! Appending weather
# Processing Record 5 city: tarija ! Appending weather
# Processing Record 6 city: port hawkesbury ! Appending weather
# Processing Record 7 city: punta arenas ! Appending weather
# Processing Record 8 city: tuatapere ! Appending weather
# Processing Record 9 city: ulaanbaatar ! Appending weather
# Processing Record 10 city: hobart ! Appending weather
# Processing Record 11 city: victoria ! Appending weather
# Processing Record 12 city: nikel ! Appending weather
# Processing Record 13 city: tasiilaq ! Appending weather
# Processing Record 14 city: leshukonskoye ! Appending weather
# city attawapiskat not found. Skipping...
# Processing Record 16 city: sinnamary ! Appending weather
# Processing Record 17 city: mataura ! Appending weather
# Processing Record 18 city: sucua ! Appending weather
# city mys shmidta not found. Skipping...
# Processing Record 20 city: usinsk ! Appending weather
# Processing Record 21 city: san lorenzo ! Appending weather
# Processing Record 22 city: avarua ! Appending weather
# Processing Record 23 city: mount gambier ! Appending weather
# Processing Record 24 city: albany ! Appending weather
# Processing Record 25 city: antofagasta ! Appending weather
# Processing Record 26 city: hermanus ! Appending weather
# Processing Record 27 city: mosquera ! Appending weather
# Processing Record 28 city: cheremukhovo ! Appending weather
# Processing Record 29 city: new norfolk ! Appending weather
# Processing Record 30 city: tura ! Appending weather
# Processing Record 31 city: puerto ayora ! Appending weather
# Processing Record 32 city: port alfred ! Appending weather
# Processing Record 33 city: sao joao da barra ! Appending weather
# city illoqqortoormiut not found. Skipping...
# Processing Record 35 city: chuy ! Appending weather
# Processing Record 36 city: camacha ! Appending weather
# Processing Record 37 city: bredasdorp ! Appending weather
# Processing Record 38 city: saldanha ! Appending weather
# Processing Record 39 city: atuona ! Appending weather
# Processing Record 40 city: busselton ! Appending weather
# Processing Record 41 city: tuktoyaktuk ! Appending weather
# Processing Record 42 city: ribeira grande ! Appending weather
# Processing Record 43 city: qaanaaq ! Appending weather
# Processing Record 44 city: barrow ! Appending weather
# Processing Record 45 city: lasa ! Appending weather
# city samusu not found. Skipping...
# Processing Record 47 city: georgetown ! Appending weather
# Processing Record 48 city: mahbubabad ! Appending weather
# Processing Record 49 city: camopi ! Appending weather
# Processing Record 50 city: kodiak ! Appending weather
# Processing Record 51 city: grindavik ! Appending weather
# Processing Record 52 city: limon ! Appending weather
# Processing Record 53 city: rikitea ! Appending weather
# Processing Record 54 city: aklavik ! Appending weather
# Processing Record 55 city: kapaa ! Appending weather
# Processing Record 56 city: korla ! Appending weather
# Processing Record 57 city: khatanga ! Appending weather
# Processing Record 58 city: yellowknife ! Appending weather
# Processing Record 59 city: butaritari ! Appending weather
# Processing Record 60 city: lorengau ! Appending weather
# Processing Record 61 city: bowen ! Appending weather
# Processing Record 62 city: leningradskiy ! Appending weather
# Processing Record 63 city: vaini ! Appending weather
# Processing Record 64 city: imbituba ! Appending weather
# Processing Record 65 city: ushuaia ! Appending weather
# Processing Record 66 city: fukue ! Appending weather
# Processing Record 67 city: hilo ! Appending weather
# Processing Record 68 city: bambous virieux ! Appending weather
# Processing Record 69 city: verkhoyansk ! Appending weather
# Processing Record 70 city: plavsk ! Appending weather
# Processing Record 71 city: jamestown ! Appending weather
# Processing Record 72 city: bluff ! Appending weather
# Processing Record 73 city: nuristan ! Appending weather
# Processing Record 74 city: mahebourg ! Appending weather
# Processing Record 75 city: gamba ! Appending weather
# Processing Record 76 city: upernavik ! Appending weather
# Processing Record 77 city: chokurdakh ! Appending weather
# Processing Record 78 city: beringovskiy ! Appending weather
# Processing Record 79 city: simbahan ! Appending weather
# Processing Record 80 city: port augusta ! Appending weather
# Processing Record 81 city: tynda ! Appending weather
# city thilogne not found. Skipping...
# Processing Record 83 city: cape town ! Appending weather
# Processing Record 84 city: unguia ! Appending weather
# city nizhneyansk not found. Skipping...
# Processing Record 86 city: qaqortoq ! Appending weather
# Processing Record 87 city: komsomolskiy ! Appending weather
# Processing Record 88 city: vieste ! Appending weather
# Processing Record 89 city: ketchikan ! Appending weather
# Processing Record 90 city: alofi ! Appending weather
# Processing Record 91 city: richards bay ! Appending weather
# Processing Record 92 city: souillac ! Appending weather
# Processing Record 93 city: aljezur ! Appending weather
# Processing Record 94 city: esperance ! Appending weather
# Processing Record 95 city: bhag ! Appending weather
# Processing Record 96 city: owando ! Appending weather
# Processing Record 97 city: churapcha ! Appending weather
# Processing Record 98 city: arraial do cabo ! Appending weather
# Processing Record 99 city: meadow lake ! Appending weather
# Processing Record 100 city: banjar ! Appending weather
# Processing Record 101 city: carnarvon ! Appending weather
# Processing Record 102 city: naivasha ! Appending weather
# Processing Record 103 city: itoman ! Appending weather
# Processing Record 104 city: dudinka ! Appending weather
# Processing Record 105 city: ussel ! Appending weather
# Processing Record 106 city: airai ! Appending weather
# Processing Record 107 city: christchurch ! Appending weather
# Processing Record 108 city: kangaatsiaq ! Appending weather
# Processing Record 109 city: moroto ! Appending weather
# city barentsburg not found. Skipping...
# Processing Record 111 city: wajima ! Appending weather
# Processing Record 112 city: geraldton ! Appending weather
# Processing Record 113 city: luderitz ! Appending weather
# Processing Record 114 city: san pedro ! Appending weather
# Processing Record 115 city: vardo ! Appending weather
# Processing Record 116 city: port elizabeth ! Appending weather
# Processing Record 117 city: la ronge ! Appending weather
# Processing Record 118 city: rusape ! Appending weather
# Processing Record 119 city: gornopravdinsk ! Appending weather
# Processing Record 120 city: eyl ! Appending weather
# Processing Record 121 city: buford ! Appending weather
# Processing Record 122 city: dunedin ! Appending weather
# Processing Record 123 city: baykit ! Appending weather
# city tumannyy not found. Skipping...
# Processing Record 125 city: san patricio ! Appending weather
# Processing Record 126 city: sangar ! Appending weather
# Processing Record 127 city: aksu ! Appending weather
# Processing Record 128 city: westport ! Appending weather
# Processing Record 129 city: takoradi ! Appending weather
# Processing Record 130 city: nikolskoye ! Appending weather
# Processing Record 131 city: najran ! Appending weather
# Processing Record 132 city: codrington ! Appending weather
# city satitoa not found. Skipping...
# Processing Record 134 city: saquarema ! Appending weather
# Processing Record 135 city: guanare ! Appending weather
# Processing Record 136 city: langxiang ! Appending weather
# Processing Record 137 city: fort nelson ! Appending weather
# Processing Record 138 city: sao jose da coroa grande ! Appending weather
# Processing Record 139 city: abha ! Appending weather
# Processing Record 140 city: olga ! Appending weather
# Processing Record 141 city: nizhniy kuranakh ! Appending weather
# Processing Record 142 city: douentza ! Appending weather
# Processing Record 143 city: husavik ! Appending weather
# Processing Record 144 city: mar del plata ! Appending weather
# Processing Record 145 city: aloleng ! Appending weather
# Processing Record 146 city: castro ! Appending weather
# Processing Record 147 city: mehamn ! Appending weather
# Processing Record 148 city: demyanovo ! Appending weather
# Processing Record 149 city: krabi ! Appending weather
# Processing Record 150 city: kapurthala ! Appending weather
# Processing Record 151 city: karatuzskoye ! Appending weather
# Processing Record 152 city: zabid ! Appending weather
# Processing Record 153 city: bethel ! Appending weather
# Processing Record 154 city: deogarh ! Appending weather
# Processing Record 155 city: bolshevik ! Appending weather
# Processing Record 156 city: hokitika ! Appending weather
# Processing Record 157 city: beyneu ! Appending weather
# Processing Record 158 city: honolulu ! Appending weather
# Processing Record 159 city: tucurui ! Appending weather
# Processing Record 160 city: muskegon ! Appending weather
# Processing Record 161 city: katsuura ! Appending weather
# city grand river south east not found. Skipping...
# Processing Record 163 city: dekar ! Appending weather
# Processing Record 164 city: oranjestad ! Appending weather
# Processing Record 165 city: gayny ! Appending weather
# Processing Record 166 city: emerald ! Appending weather
# Processing Record 167 city: nanortalik ! Appending weather
# Processing Record 168 city: muros ! Appending weather
# Processing Record 169 city: thompson ! Appending weather
# Processing Record 170 city: miri ! Appending weather
# Processing Record 171 city: havelock ! Appending weather
# Processing Record 172 city: maku ! Appending weather
# Processing Record 173 city: garowe ! Appending weather
# Processing Record 174 city: vila velha ! Appending weather
# Processing Record 175 city: hasaki ! Appending weather
# Processing Record 176 city: krasnoselkup ! Appending weather
# Processing Record 177 city: conceicao da barra ! Appending weather
# Processing Record 178 city: ukiah ! Appending weather
# Processing Record 179 city: te anau ! Appending weather
# Processing Record 180 city: awbari ! Appending weather
# Processing Record 181 city: pevek ! Appending weather
# Processing Record 182 city: umm kaddadah ! Appending weather
# Processing Record 183 city: ust-kulom ! Appending weather
# Processing Record 184 city: buguda ! Appending weather
# Processing Record 185 city: asfi ! Appending weather
# Processing Record 186 city: witu ! Appending weather
# Processing Record 187 city: east london ! Appending weather
# Processing Record 188 city: izumo ! Appending weather
# Processing Record 189 city: huiloapan ! Appending weather
# Processing Record 190 city: bengkulu ! Appending weather
# Processing Record 191 city: batticaloa ! Appending weather
# Processing Record 192 city: aasiaat ! Appending weather
# Processing Record 193 city: elizabeth city ! Appending weather
# Processing Record 194 city: ponta do sol ! Appending weather
# Processing Record 195 city: holbeach ! Appending weather
# Processing Record 196 city: kulhudhuffushi ! Appending weather
# Processing Record 197 city: hendek ! Appending weather
# Processing Record 198 city: santa fe ! Appending weather
# Processing Record 199 city: banyo ! Appending weather
# Processing Record 200 city: hornepayne ! Appending weather
# Processing Record 201 city: sao felix do xingu ! Appending weather
# Processing Record 202 city: fairbanks ! Appending weather
# Processing Record 203 city: kovdor ! Appending weather
# Processing Record 204 city: kirakira ! Appending weather
# Processing Record 205 city: honiara ! Appending weather
# Processing Record 206 city: nokaneng ! Appending weather
# Processing Record 207 city: cabo san lucas ! Appending weather
# Processing Record 208 city: tiksi ! Appending weather
# Processing Record 209 city: dickinson ! Appending weather
# Processing Record 210 city: provideniya ! Appending weather
# Processing Record 211 city: cascais ! Appending weather
# Processing Record 212 city: los llanos de aridane ! Appending weather
# Processing Record 213 city: longyearbyen ! Appending weather
# Processing Record 214 city: lazo ! Appending weather
# Processing Record 215 city: tautira ! Appending weather
# Processing Record 216 city: ormara ! Appending weather
# Processing Record 217 city: walvis bay ! Appending weather
# city kuche not found. Skipping...
# Processing Record 219 city: tupik ! Appending weather
# Processing Record 220 city: isiro ! Appending weather
# Processing Record 221 city: vila ! Appending weather
# Processing Record 222 city: dingle ! Appending weather
# Processing Record 223 city: matara ! Appending weather
# Processing Record 224 city: hamilton ! Appending weather
# Processing Record 225 city: port lincoln ! Appending weather
# Processing Record 226 city: padang ! Appending weather
# Processing Record 227 city: tuim ! Appending weather
# Processing Record 228 city: lipin bor ! Appending weather
# Processing Record 229 city: coihaique ! Appending weather
# Processing Record 230 city: seybaplaya ! Appending weather
# Processing Record 231 city: pisco ! Appending weather
# Processing Record 232 city: linxia ! Appending weather
# city bolungarvik not found. Skipping...
# Processing Record 234 city: norman wells ! Appending weather
# city sentyabrskiy not found. Skipping...
# Processing Record 236 city: cherskiy ! Appending weather
# Processing Record 237 city: kahului ! Appending weather
# Processing Record 238 city: asau ! Appending weather
# Processing Record 239 city: robertsport ! Appending weather
# Processing Record 240 city: sala consilina ! Appending weather
# Processing Record 241 city: dawlatabad ! Appending weather
# Processing Record 242 city: seydi ! Appending weather
# Processing Record 243 city: waddan ! Appending weather
# Processing Record 244 city: dikson ! Appending weather
# Processing Record 245 city: salta ! Appending weather
# Processing Record 246 city: alice springs ! Appending weather
# Processing Record 247 city: cordoba ! Appending weather
# Processing Record 248 city: quang ngai ! Appending weather
# Processing Record 249 city: acarau ! Appending weather
# Processing Record 250 city: lugano ! Appending weather
# city vaitupu not found. Skipping...
# Processing Record 252 city: saint-pierre ! Appending weather
# Processing Record 253 city: torbay ! Appending weather
# Processing Record 254 city: palmer ! Appending weather
# city palabuhanratu not found. Skipping...
# Processing Record 256 city: avera ! Appending weather
# Processing Record 257 city: saurimo ! Appending weather
# Processing Record 258 city: khandyga ! Appending weather
# Processing Record 259 city: skibbereen ! Appending weather
# Processing Record 260 city: hithadhoo ! Appending weather
# city saleaula not found. Skipping...
# Processing Record 262 city: colares ! Appending weather
# Processing Record 263 city: ust-kuyga ! Appending weather
# Processing Record 264 city: west bay ! Appending weather
# Processing Record 265 city: faanui ! Appending weather
# Processing Record 266 city: cidreira ! Appending weather
# Processing Record 267 city: lebu ! Appending weather
# Processing Record 268 city: meulaboh ! Appending weather
# Processing Record 269 city: fethiye ! Appending weather
# Processing Record 270 city: alexandria ! Appending weather
# Processing Record 271 city: ouesso ! Appending weather
# city karaul not found. Skipping...
# Processing Record 273 city: kudahuvadhoo ! Appending weather
# Processing Record 274 city: benjamin constant ! Appending weather
# Processing Record 275 city: cayenne ! Appending weather
# Processing Record 276 city: srednekolymsk ! Appending weather
# Processing Record 277 city: upington ! Appending weather
# city tabiauea not found. Skipping...
# Processing Record 279 city: fomboni ! Appending weather
# Processing Record 280 city: caravelas ! Appending weather
# Processing Record 281 city: kununurra ! Appending weather
# Processing Record 282 city: constitucion ! Appending weather
# Processing Record 283 city: bonavista ! Appending weather
# Processing Record 284 city: nyrob ! Appending weather
# Processing Record 285 city: erzin ! Appending weather
# Processing Record 286 city: sabang ! Appending weather
# city hihifo not found. Skipping...
# Processing Record 288 city: kozhva ! Appending weather
# Processing Record 289 city: poso ! Appending weather
# Processing Record 290 city: samarai ! Appending weather
# Processing Record 291 city: sitka ! Appending weather
# Processing Record 292 city: worland ! Appending weather
# Processing Record 293 city: kutum ! Appending weather
# Processing Record 294 city: sassandra ! Appending weather
# Processing Record 295 city: starkville ! Appending weather
# Processing Record 296 city: yilan ! Appending weather
# Processing Record 297 city: saint george ! Appending weather
# Processing Record 298 city: bako ! Appending weather
# Processing Record 299 city: benguela ! Appending weather
# Processing Record 300 city: benghazi ! Appending weather
# Processing Record 301 city: labuhan ! Appending weather
# Processing Record 302 city: hofn ! Appending weather
# city amderma not found. Skipping...
# Processing Record 304 city: sept-iles ! Appending weather
# Processing Record 305 city: tomatlan ! Appending weather
# city yirol not found. Skipping...
# Processing Record 307 city: benalla ! Appending weather
# Processing Record 308 city: vichy ! Appending weather
# Processing Record 309 city: chicama ! Appending weather
# Processing Record 310 city: maniitsoq ! Appending weather
# Processing Record 311 city: laguna ! Appending weather
# Processing Record 312 city: tromso ! Appending weather
# Processing Record 313 city: arman ! Appending weather
# Processing Record 314 city: paulista ! Appending weather
# Processing Record 315 city: bathsheba ! Appending weather
# city korogwe not found. Skipping...
# Processing Record 317 city: ilulissat ! Appending weather
# Processing Record 318 city: ekhabi ! Appending weather
# Processing Record 319 city: saskylakh ! Appending weather
# Processing Record 320 city: severo-kurilsk ! Appending weather
# Processing Record 321 city: mataram ! Appending weather
# Processing Record 322 city: praia da vitoria ! Appending weather
# Processing Record 323 city: abonnema ! Appending weather
# Processing Record 324 city: mbulu ! Appending weather
# Processing Record 325 city: maningrida ! Appending weather
# Processing Record 326 city: narsaq ! Appending weather
# city monte cristi not found. Skipping...
# Processing Record 328 city: ishinomaki ! Appending weather
# Processing Record 329 city: grand gaube ! Appending weather
# Processing Record 330 city: bilma ! Appending weather
# Processing Record 331 city: egvekinot ! Appending weather
# Processing Record 332 city: abhaynagar ! Appending weather
# Processing Record 333 city: sale ! Appending weather
# Processing Record 334 city: pechora ! Appending weather
# Processing Record 335 city: ambilobe ! Appending weather
# Processing Record 336 city: bom jesus ! Appending weather
# Processing Record 337 city: atar ! Appending weather
# city angra not found. Skipping...
# Processing Record 339 city: saint anthony ! Appending weather
# Processing Record 340 city: necochea ! Appending weather
# Processing Record 341 city: tombouctou ! Appending weather
# Processing Record 342 city: biak ! Appending weather
# Processing Record 343 city: catuday ! Appending weather
# Processing Record 344 city: chernyshevskiy ! Appending weather
# Processing Record 345 city: swan hill ! Appending weather
# Processing Record 346 city: puri ! Appending weather
# Processing Record 347 city: clyde river ! Appending weather
# Processing Record 348 city: mahon ! Appending weather
# Processing Record 349 city: faribault ! Appending weather
# Processing Record 350 city: coquimbo ! Appending weather
# Processing Record 351 city: cap-aux-meules ! Appending weather
# Processing Record 352 city: diego de almagro ! Appending weather
# Processing Record 353 city: deep river ! Appending weather
# Processing Record 354 city: trinidad ! Appending weather
# Processing Record 355 city: haines junction ! Appending weather
# Processing Record 356 city: puerto escondido ! Appending weather
# Processing Record 357 city: ozernovskiy ! Appending weather
# Processing Record 358 city: olafsvik ! Appending weather
# Processing Record 359 city: miandrivazo ! Appending weather
# Processing Record 360 city: bagotville ! Appending weather
# Processing Record 361 city: klaksvik ! Appending weather
# Processing Record 362 city: nargana ! Appending weather
# Processing Record 363 city: moundsville ! Appending weather
# Processing Record 364 city: taltal ! Appending weather
# Processing Record 365 city: salalah ! Appending weather
# Processing Record 366 city: tabou ! Appending weather
# Processing Record 367 city: bandipur ! Appending weather
# Processing Record 368 city: normandin ! Appending weather
# Processing Record 369 city: kuito ! Appending weather
# Processing Record 370 city: chunskiy ! Appending weather
# Processing Record 371 city: nipawin ! Appending weather
# Processing Record 372 city: touros ! Appending weather
# Processing Record 373 city: puerto leguizamo ! Appending weather
# Processing Record 374 city: pacific grove ! Appending weather
# Processing Record 375 city: namibe ! Appending weather
# Processing Record 376 city: kariba ! Appending weather
# Processing Record 377 city: port hedland ! Appending weather
# Processing Record 378 city: atasu ! Appending weather
# Processing Record 379 city: byumba ! Appending weather
# Processing Record 380 city: kimbe ! Appending weather
# Processing Record 381 city: banda aceh ! Appending weather
# city bargal not found. Skipping...
# Processing Record 383 city: nagornyy ! Appending weather
# city okandja not found. Skipping...
# Processing Record 385 city: flinders ! Appending weather
# Processing Record 386 city: russell ! Appending weather
# Processing Record 387 city: san andres ! Appending weather
# Processing Record 388 city: rudnyy ! Appending weather
# city karamay not found. Skipping...
# Processing Record 390 city: henties bay ! Appending weather
# city saryshagan not found. Skipping...
# Processing Record 392 city: la joya ! Appending weather
# Processing Record 393 city: saint-philippe ! Appending weather
# Processing Record 394 city: talnakh ! Appending weather
# Processing Record 395 city: cheyenne ! Appending weather
# Processing Record 396 city: naze ! Appending weather
# Processing Record 397 city: nuuk ! Appending weather
# Processing Record 398 city: srandakan ! Appending weather
# Processing Record 399 city: north bend ! Appending weather
# Processing Record 400 city: bad hofgastein ! Appending weather
# Processing Record 401 city: zyuzelskiy ! Appending weather
# Processing Record 402 city: dawei ! Appending weather
# Processing Record 403 city: bud ! Appending weather
# Processing Record 404 city: yulara ! Appending weather
# Processing Record 405 city: totness ! Appending weather
# Processing Record 406 city: pundaguitan ! Appending weather
# Processing Record 407 city: gushikawa ! Appending weather
# city chengmai not found. Skipping...
# Processing Record 409 city: yerbogachen ! Appending weather
# Processing Record 410 city: belomorsk ! Appending weather
# Processing Record 411 city: lincoln ! Appending weather
# Processing Record 412 city: kavaratti ! Appending weather
# city meyungs not found. Skipping...
# Processing Record 414 city: san policarpo ! Appending weather
# Processing Record 415 city: gat ! Appending weather
# Processing Record 416 city: altay ! Appending weather
# Processing Record 417 city: kathmandu ! Appending weather
# Processing Record 418 city: chancay ! Appending weather
# Processing Record 419 city: timberlake ! Appending weather
# Processing Record 420 city: pechenga ! Appending weather
# Processing Record 421 city: rio grande ! Appending weather
# Processing Record 422 city: saint-augustin ! Appending weather
# Processing Record 423 city: vagur ! Appending weather
# Processing Record 424 city: thai nguyen ! Appending weather
# Processing Record 425 city: manaure ! Appending weather
# Processing Record 426 city: ribita ! Appending weather
# city tsihombe not found. Skipping...
# Processing Record 428 city: cairns ! Appending weather
# Processing Record 429 city: maumere ! Appending weather
# Processing Record 430 city: huarmey ! Appending weather
# Processing Record 431 city: keti bandar ! Appending weather
# Processing Record 432 city: lagoa ! Appending weather
# Processing Record 433 city: mossendjo ! Appending weather
# Processing Record 434 city: talara ! Appending weather
# Processing Record 435 city: zhanaozen ! Appending weather
# Processing Record 436 city: curup ! Appending weather
# Processing Record 437 city: cortez ! Appending weather
# Processing Record 438 city: qandala ! Appending weather
# Processing Record 439 city: noumea ! Appending weather
# Processing Record 440 city: abancay ! Appending weather
# city buqayq not found. Skipping...
# Processing Record 442 city: guarapari ! Appending weather
# Processing Record 443 city: sai buri ! Appending weather
# Processing Record 444 city: tumut ! Appending weather
# Processing Record 445 city: kaitangata ! Appending weather
# Processing Record 446 city: shangrao ! Appending weather
# Processing Record 447 city: miraflores ! Appending weather
# Processing Record 448 city: sao gabriel da cachoeira ! Appending weather
# Processing Record 449 city: entre rios ! Appending weather
# Processing Record 450 city: naryan-mar ! Appending weather
# Processing Record 451 city: tanete ! Appending weather
# Processing Record 452 city: sochi ! Appending weather
# Processing Record 453 city: tenancingo ! Appending weather
# Processing Record 454 city: san quintin ! Appending weather
# Processing Record 455 city: adrar ! Appending weather
# Processing Record 456 city: killybegs ! Appending weather
# Processing Record 457 city: jawhar ! Appending weather
# Processing Record 458 city: nsanje ! Appending weather
# Processing Record 459 city: chokwe ! Appending weather
# Processing Record 460 city: chapais ! Appending weather
# Processing Record 461 city: tilichiki ! Appending weather
# Processing Record 462 city: hualmay ! Appending weather
# Processing Record 463 city: margate ! Appending weather
# Processing Record 464 city: atambua ! Appending weather
# Processing Record 465 city: puerto cabezas ! Appending weather
# Processing Record 466 city: sao filipe ! Appending weather
# Processing Record 467 city: celestun ! Appending weather
# Processing Record 468 city: luanda ! Appending weather
# Processing Record 469 city: osecina ! Appending weather
# Processing Record 470 city: whitehorse ! Appending weather
# Processing Record 471 city: ghanzi ! Appending weather
# Processing Record 472 city: severobaykalsk ! Appending weather
# Processing Record 473 city: charters towers ! Appending weather
# Processing Record 474 city: agadez ! Appending weather
# Processing Record 475 city: ilhabela ! Appending weather
# Processing Record 476 city: san juan ! Appending weather
# Processing Record 477 city: ulladulla ! Appending weather
# Processing Record 478 city: margherita ! Appending weather
# Processing Record 479 city: road town ! Appending weather
# Processing Record 480 city: shimoda ! Appending weather
# city gurskoye not found. Skipping...
# Processing Record 482 city: teofilo otoni ! Appending weather
# Processing Record 483 city: ahuimanu ! Appending weather
# Processing Record 484 city: poum ! Appending weather
# Processing Record 485 city: sillod ! Appending weather
# Processing Record 486 city: tonantins ! Appending weather
# Processing Record 487 city: toora-khem ! Appending weather
# Processing Record 488 city: saulkrasti ! Appending weather
# Processing Record 489 city: bridgetown ! Appending weather
# Processing Record 490 city: kruisfontein ! Appending weather
# Processing Record 491 city: burnie ! Appending weather
# Processing Record 492 city: hit ! Appending weather
# Processing Record 493 city: mehran ! Appending weather
# Processing Record 494 city: nara ! Appending weather
# Processing Record 495 city: cabinda ! Appending weather
# Processing Record 496 city: zhireken ! Appending weather
# Processing Record 497 city: lokosovo ! Appending weather
# Processing Record 498 city: zhigansk ! Appending weather
# Processing Record 499 city: panzhihua ! Appending weather
# Processing Record 500 city: camocim ! Appending weather
# Processing Record 501 city: hovd ! Appending weather
# Processing Record 502 city: mao ! Appending weather
# Processing Record 503 city: saint-louis ! Appending weather
# Processing Record 504 city: alugan ! Appending weather
# city el badari not found. Skipping...
# Processing Record 506 city: port keats ! Appending weather
# Processing Record 507 city: liverpool ! Appending weather
# city mahadday weyne not found. Skipping...
# Processing Record 509 city: nakhon phanom ! Appending weather
# Processing Record 510 city: ancud ! Appending weather
# city ondorhaan not found. Skipping...
# Processing Record 512 city: ambanja ! Appending weather
# Processing Record 513 city: copiapo ! Appending weather
# Processing Record 514 city: ixtapa ! Appending weather
# Processing Record 515 city: gogrial ! Appending weather
# city one hundred mile house not found. Skipping...
# Processing Record 517 city: qidong ! Appending weather
# Processing Record 518 city: ugoofaaru ! Appending weather
# Processing Record 519 city: nueva loja ! Appending weather
# city lolua not found. Skipping...
# Processing Record 521 city: adamas ! Appending weather
# Processing Record 522 city: sobolevo ! Appending weather
# Processing Record 523 city: mayo ! Appending weather
# Processing Record 524 city: rawson ! Appending weather
# Processing Record 525 city: oktyabrskiy ! Appending weather
# Processing Record 526 city: reporoa ! Appending weather
# Processing Record 527 city: nantucket ! Appending weather
# city mrirt not found. Skipping...
# Processing Record 529 city: havoysund ! Appending weather
# Processing Record 530 city: chilca ! Appending weather
# Processing Record 531 city: una ! Appending weather
# Processing Record 532 city: novobiryusinskiy ! Appending weather
# Processing Record 533 city: mareeba ! Appending weather
# Processing Record 534 city: aykhal ! Appending weather
# city barawe not found. Skipping...
# Processing Record 536 city: kieta ! Appending weather
# Processing Record 537 city: mogadishu ! Appending weather
# Processing Record 538 city: lewiston ! Appending weather
# city marcona not found. Skipping...
# Processing Record 540 city: plettenberg bay ! Appending weather
# Processing Record 541 city: hanamaki ! Appending weather
# Processing Record 542 city: cape canaveral ! Appending weather
# Processing Record 543 city: arrecife ! Appending weather
# Processing Record 544 city: maldonado ! Appending weather
# Processing Record 545 city: chapeco ! Appending weather
# Processing Record 546 city: tahta ! Appending weather
# Processing Record 547 city: pyapon ! Appending weather
# Processing Record 548 city: nainpur ! Appending weather
# Processing Record 549 city: marsa matruh ! Appending weather
# Processing Record 550 city: andenes ! Appending weather
# Processing Record 551 city: mumford ! Appending weather
# Processing Record 552 city: darab ! Appending weather
# Processing Record 553 city: isangel ! Appending weather
# Processing Record 554 city: dongsheng ! Appending weather
# Processing Record 555 city: labuan ! Appending weather
# Processing Record 556 city: gannan ! Appending weather
# Processing Record 557 city: fortuna ! Appending weather
# Processing Record 558 city: lukulu ! Appending weather
# Processing Record 559 city: mayor pablo lagerenza ! Appending weather
# Processing Record 560 city: wankaner ! Appending weather
# Processing Record 561 city: san ramon ! Appending weather
# Processing Record 562 city: pontes e lacerda ! Appending weather
# Processing Record 563 city: saint-joseph ! Appending weather
# Processing Record 564 city: hervey bay ! Appending weather
# Processing Record 565 city: finote selam ! Appending weather
# Processing Record 566 city: southbridge ! Appending weather
# Processing Record 567 city: dauphin ! Appending weather
# Processing Record 568 city: rzhaksa ! Appending weather
# Processing Record 569 city: moree ! Appending weather
# city babanusah not found. Skipping...
# Processing Record 571 city: toktogul ! Appending weather
# Processing Record 572 city: anzio ! Appending weather
# Processing Record 573 city: banfora ! Appending weather
# Processing Record 574 city: paita ! Appending weather
# Processing Record 575 city: moanda ! Appending weather
# Processing Record 576 city: vermilion ! Appending weather
# Processing Record 577 city: mount isa ! Appending weather
# Processing Record 578 city: nurota ! Appending weather
# Processing Record 579 city: sioux lookout ! Appending weather
# Processing Record 580 city: makaha ! Appending weather
# Processing Record 581 city: humaita ! Appending weather
# Processing Record 582 city: waipawa ! Appending weather
# Processing Record 583 city: ballarat ! Appending weather
# Processing Record 584 city: rock sound ! Appending weather
# Processing Record 585 city: faya ! Appending weather
# Processing Record 586 city: lumeje ! Appending weather
# Processing Record 587 city: birjand ! Appending weather
# Processing Record 588 city: hambantota ! Appending weather
# Processing Record 589 city: hopelchen ! Appending weather
# Processing Record 590 city: solnechnyy ! Appending weather
# Processing Record 591 city: kargasok ! Appending weather
# Processing Record 592 city: salinopolis ! Appending weather
# Processing Record 593 city: doba ! Appending weather
# Processing Record 594 city: okha ! Appending weather
# Processing Record 595 city: alta floresta ! Appending weather
# Processing Record 596 city: begowal ! Appending weather
# Processing Record 597 city: hohhot ! Appending weather
# Processing Record 598 city: vanimo ! Appending weather
# --------------------------
# Data Retrieval Complete
# --------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create lists to store relevant data
city = []
country = []
date = []
lat = []
lon = []
temp_max = []
humidity = []
cloudiness = []
wind_speed = []

# Loop thru the response list
for i in range(len(weather_data)):
    city.append(weather_data[i]['name'])
    date.append(weather_data[i]['dt'])
    country.append(weather_data[i]['sys']['country'])
    lat.append(weather_data[i]['coord']['lat'])
    lon.append(weather_data[i]['coord']['lon'])
    temp_max.append(weather_data[i]['main']['temp_max'])
    humidity.append(weather_data[i]['main']['humidity'])
    cloudiness.append(weather_data[i]['clouds']['all'])
    wind_speed.append(weather_data[i]['wind']['speed'])

# Convert raw data to DataFrame
weather_df = pd.DataFrame({"City" : city,
                           "Cloudiness": cloudiness,
                           "Country":country,
                           "Date": date,
                           "Humidity" : humidity,
                           "Lat": lat,
                           "Lng": lon,
                           "Max Temp": temp_max,
                           "Wind Speed": wind_speed})
weather_df.head()

# Export the data into csv
weather_df.to_csv('weather_data.csv',index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df['Lat'], weather_df['Max Temp'], marker='o')

# Incorporate the other graph properties
plt.title(f'City Latitude vs Max Temperature {datetime.today().date()}')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid('True')

# Save the figure
plt.savefig('visuals/max-temp.png')

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df['Lat'], weather_df['Humidity'], marker='o')

# Incorporate the other graph properties
plt.title(f'City Latitude vs Humidity Plot {datetime.today().date()}')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid('True')

# Save the figure
plt.savefig('visuals/humidity.png')

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df['Lat'], weather_df['Cloudiness'], marker='o')

# Incorporate the other graph properties
plt.title(f'City Latitude vs Cloudiness {datetime.today().date()}')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid('True')

# Save the figure
plt.savefig('visuals/cloudiness.png')

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df['Lat'], weather_df['Wind Speed'], marker='o')

# Incorporate the other graph properties
plt.title(f'City Latitude vs Wind Speed {datetime.today().date()}')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid('True')

# Save the figure
plt.savefig('visuals/wind-speed.png')

# Show plot
plt.show()

# %%
# Southern Hemisphere vs Max Temp
south_hemisphere = weather_df.loc[weather_df['Lat'] < 0]

# Assign x , y values
x_val = south_hemisphere['Lat']
y_val = south_hemisphere['Max Temp']

# Perform linear regreession
s_slope, s_int, s_r, s_p, s_err = st.linregress(x_val, y_val)
s_fit = x_val * s_slope + s_int

plt.scatter(x_val,y_val)
plt.plot(x_val,s_fit,"b-")


plt.title(f'Southern Hemisphere Latitude vs Max Temperature {datetime.today().date()}')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid('True')

# Save the figure
plt.savefig('visuals/SouthLatvsTemp.png')

# Show plot
plt.show()

# %%
# Assign x , y values
x_val = south_hemisphere['Lat']
y_val = south_hemisphere['Humidity']

# Perform linear regreession
s_slope, s_int, s_r, s_p, s_err = st.linregress(x_val, y_val)
s_fit = x_val * s_slope + s_int

plt.scatter(x_val,y_val)
plt.plot(x_val,s_fit,"b-")

plt.title(f'Southern Hemisphere Latitude vs Humidity (%) {datetime.today().date()}')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid('True')

# Save the figure
plt.savefig('visuals/SouthLatvsHumidity.png')

# Show plot
plt.show()

# %%
# Assign x , y values
x_val = south_hemisphere['Lat']
y_val = south_hemisphere['Cloudiness']

# Perform linear regreession
s_slope, s_int, s_r, s_p, s_err = st.linregress(x_val, y_val)
s_fit = x_val * s_slope + s_int

plt.scatter(x_val,y_val)
plt.plot(x_val,s_fit,"b-")

plt.title(f'Southern Hemisphere Latitude vs Cloudiness (%) {datetime.today().date()}')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid('True')

# Save the figure
plt.savefig('visuals/SouthLatvsCloudiness.png')

# Show plot
plt.show()

# %%
# Assign x , y values
x_val = south_hemisphere['Lat']
y_val = south_hemisphere['Wind Speed']

# Perform linear regreession
s_slope, s_int, s_r, s_p, s_err = st.linregress(x_val, y_val)
s_fit = x_val * s_slope + s_int

plt.scatter(x_val,y_val)
plt.plot(x_val,s_fit,"b-")

plt.title(f'Southern Hemisphere Latitude vs Wind Speed (mph) {datetime.today().date()}')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid('True')

# Save the figure
plt.savefig('visuals/SouthLatvsWindSpeed.png')

# Show plot
plt.show()

# %%
# Set latitude for Northern Hemisphere 
north_hemisphere = weather_df.loc[weather_df['Lat'] < 0]

# Assign x , y values
x_val = north_hemisphere['Lat']
y_val = north_hemisphere['Wind Speed']

# Perform linear regreession
n_slope, n_int, n_r, n_p, n_err = st.linregress(x_val, y_val)
n_fit = x_val * n_slope + n_int

plt.scatter(x_val,y_val)
plt.plot(x_val,n_fit,"b-")

plt.title(f'Northern Hemisphere Latitude vs Wind Speed (mph) {datetime.today().date()}')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid('True')

# Save the figure
plt.savefig('visuals/NorthLatvsWindSpeed.png')

# Show plot
plt.show()

# %%
# Assign x , y values
x_val = north_hemisphere['Lat']
y_val = north_hemisphere['Cloudiness']

# Perform linear regreession
n_slope, n_int, n_r, n_p, n_err = st.linregress(x_val, y_val)
n_fit = x_val * n_slope + n_int

plt.scatter(x_val,y_val)
plt.plot(x_val,n_fit,"b-")

plt.title(f'Northern Hemisphere Latitude vs Cloudiness (%) {datetime.today().date()}')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid('True')

# Save the figure
plt.savefig('visuals/NorthLatvsCloudiness.png')

# Show plot
plt.show()

# %%
# Assign x , y values
x_val = north_hemisphere['Lat']
y_val = north_hemisphere['Humidity']

# Perform linear regreession
n_slope, n_int, n_r, n_p, n_err = st.linregress(x_val, y_val)
n_fit = x_val * n_slope + n_int

plt.scatter(x_val,y_val)
plt.plot(x_val,n_fit,"b-")

plt.title(f'Northern Hemisphere Latitude vs Humidity (%) {datetime.today().date()}')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid('True')

# Save the figure
plt.savefig('visuals/NorthLatvsHumidity.png')

# Show plot
plt.show()

# %%
# Assign x , y values
x_val = north_hemisphere['Lat']
y_val = north_hemisphere['Max Temp']

# Perform linear regreession
n_slope, n_int, n_r, n_p, n_err = st.linregress(x_val, y_val)
n_fit = x_val * n_slope + n_int

plt.scatter(x_val,y_val)
plt.plot(x_val,n_fit,"b-")

plt.title(f'Northern Hemisphere Latitude vs Max Temp (F) {datetime.today().date()}')
plt.ylabel('Max Temp (F)')
plt.xlabel('Latitude')
plt.grid('True')

# Save the figure
plt.savefig('visuals/NorthLatvsMaxTemp.png')

# Show plot
plt.show()
